# %%
# Import all the necessary packages
import os
import pyodbc    
from dotenv import dotenv_values
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load environment variables from .env file into a dictionary
environment_variables = dotenv_values('.env')


# Get the values for the credentials you set in the '.env' file
server = environment_variables.get("SERVER")
database = environment_variables.get("DATABASE")
username = environment_variables.get("USER")
password = environment_variables.get("PASSWORD")

# Create a connection string
connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
# Create a connection string
connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
# Use the connect method of the pyodbc library and pass in the connection string.
connection = pyodbc.connect(connection_string)

# %%
# access july table
query = "SELECT * FROM Sales_July_2019"

data_july = pd.read_sql(query, connection)
data_july
# Out:
#        Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0      222910.0  Apple Airpods Headphones               1.0  150.000000
# 1      222911.0             Flatscreen TV               1.0  300.000000
# 2      222912.0     AA Batteries (4-pack)               1.0    3.840000
# 3      222913.0     AA Batteries (4-pack)               1.0    3.840000
# 4      222914.0    AAA Batteries (4-pack)               5.0    2.990000
# ...         ...                       ...               ...         ...
# 14366  236665.0          Wired Headphones               1.0   11.990000
# 14367  236666.0              20in Monitor               1.0  109.989998
# 14368  236667.0    AAA Batteries (4-pack)               1.0    2.990000
# 14369  236668.0          Wired Headphones               1.0   11.990000
# 14370  236669.0    AAA Batteries (4-pack)               1.0    2.990000
#
#                         Order_Date                      Purchase_Address
# ...

# %%
# save July data 
data_july.to_csv('july_data',index=False)

# %%
 # access aug table
query = "SELECT * FROM Sales_August_2019"

data_aug = pd.read_sql(query, connection)
data_aug
# Out:
#        Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0      236670.0            Wired Headphones               2.0   11.990000
# 1      236671.0  Bose SoundSport Headphones               1.0   99.989998
# 2      236672.0                      iPhone               1.0  700.000000
# 3      236673.0       AA Batteries (4-pack)               2.0    3.840000
# 4      236674.0       AA Batteries (4-pack)               2.0    3.840000
# ...         ...                         ...               ...         ...
# 12006  248146.0  Bose SoundSport Headphones               1.0   99.989998
# 12007  248147.0      AAA Batteries (4-pack)               3.0    2.990000
# 12008  248148.0       AA Batteries (4-pack)               1.0    3.840000
# 12009  248149.0        USB-C Charging Cable               1.0   11.950000
# 12010  248150.0       AA Batteries (4-pack)               1.0    3.840000
#
#                         Order_Date                         Purchase_Address
# ...

# %%
# save auguest data
data_aug.to_csv('aug_data', index=False)

# %%
#
july = pd.read_csv('july_data')
july
# Out:
#        Order_ID                   Product  Quantity_Ordered  Price_Each  \
# 0      222910.0  Apple Airpods Headphones               1.0  150.000000
# 1      222911.0             Flatscreen TV               1.0  300.000000
# 2      222912.0     AA Batteries (4-pack)               1.0    3.840000
# 3      222913.0     AA Batteries (4-pack)               1.0    3.840000
# 4      222914.0    AAA Batteries (4-pack)               5.0    2.990000
# ...         ...                       ...               ...         ...
# 14366  236665.0          Wired Headphones               1.0   11.990000
# 14367  236666.0              20in Monitor               1.0  109.989998
# 14368  236667.0    AAA Batteries (4-pack)               1.0    2.990000
# 14369  236668.0          Wired Headphones               1.0   11.990000
# 14370  236669.0    AAA Batteries (4-pack)               1.0    2.990000
#
#                         Order_Date                      Purchase_Address
# ...

# %%
query = "SELECT * FROM Sales_September_2019"

data_sep= pd.read_sql(query, connection)
data_sep
# Out:
#        Order_ID                 Product  Quantity_Ordered  Price_Each  \
# 0      248151.0   AA Batteries (4-pack)               4.0    3.840000
# 1      248152.0    USB-C Charging Cable               2.0   11.950000
# 2      248153.0    USB-C Charging Cable               1.0   11.950000
# 3      248154.0        27in FHD Monitor               1.0  149.990005
# 4      248155.0    USB-C Charging Cable               1.0   11.950000
# ...         ...                     ...               ...         ...
# 11681  259353.0  AAA Batteries (4-pack)               3.0    2.990000
# 11682  259354.0                  iPhone               1.0  700.000000
# 11683  259355.0                  iPhone               1.0  700.000000
# 11684  259356.0  34in Ultrawide Monitor               1.0  379.989990
# 11685  259357.0    USB-C Charging Cable               1.0   11.950000
#
#                         Order_Date                         Purchase_Address
# ...

# %%
data_sep.to_csv('sep_data',index=False)

# %%
query = "SELECT * FROM Sales_October_2019"

data_oct= pd.read_sql(query, connection)
data_oct
# Out:
#        Order_ID                 Product  Quantity_Ordered  Price_Each  \
# 0      259358.0  34in Ultrawide Monitor               1.0  379.989990
# 1      259359.0  27in 4K Gaming Monitor               1.0  389.989990
# 2      259360.0  AAA Batteries (4-pack)               2.0    2.990000
# 3      259361.0        27in FHD Monitor               1.0  149.990005
# 4      259362.0        Wired Headphones               1.0   11.990000
# ...         ...                     ...               ...         ...
# 20374  278792.0   AA Batteries (4-pack)               1.0    3.840000
# 20375  278793.0        Wired Headphones               1.0   11.990000
# 20376  278794.0   AA Batteries (4-pack)               1.0    3.840000
# 20377  278795.0                  iPhone               1.0  700.000000
# 20378  278796.0        Wired Headphones               1.0   11.990000
#
#                         Order_Date                           Purchase_Address
# ...

# %%
data_oct.to_csv('oct_data',index=False)

# %%
query = "SELECT * FROM Sales_November_2019"

data_nov= pd.read_sql(query, connection)
data_nov
# Out:
#        Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0      278797.0            Wired Headphones               1.0   11.990000
# 1      278798.0        USB-C Charging Cable               2.0   11.950000
# 2      278799.0    Apple Airpods Headphones               1.0  150.000000
# 3      278800.0            27in FHD Monitor               1.0  149.990005
# 4      278801.0  Bose SoundSport Headphones               1.0   99.989998
# ...         ...                         ...               ...         ...
# 17656  295660.0      AAA Batteries (4-pack)               2.0    2.990000
# 17657  295661.0        USB-C Charging Cable               1.0   11.950000
# 17658  295662.0    Lightning Charging Cable               1.0   14.950000
# 17659  295663.0      AAA Batteries (4-pack)               1.0    2.990000
# 17660  295664.0                Google Phone               1.0  600.000000
#
#                         Order_Date                      Purchase_Address
# ...

# %%
data_nov.to_csv('nov_data',index=False)

# %%
query = "SELECT * FROM Sales_December_2019"

data_dec= pd.read_sql(query, connection)
data_dec
# Out:
#        Order_ID                     Product  Quantity_Ordered   Price_Each  \
# 0      295665.0          Macbook Pro Laptop               1.0  1700.000000
# 1      295666.0          LG Washing Machine               1.0   600.000000
# 2      295667.0        USB-C Charging Cable               1.0    11.950000
# 3      295668.0            27in FHD Monitor               1.0   149.990005
# 4      295669.0        USB-C Charging Cable               1.0    11.950000
# ...         ...                         ...               ...          ...
# 25112  319666.0    Lightning Charging Cable               1.0    14.950000
# 25113  319667.0       AA Batteries (4-pack)               2.0     3.840000
# 25114  319668.0             Vareebadd Phone               1.0   400.000000
# 25115  319669.0            Wired Headphones               1.0    11.990000
# 25116  319670.0  Bose SoundSport Headphones               1.0    99.989998
#
# ...

# %%
data_dec.to_csv('dec_data',index=False)

# %%
dec = pd.read_csv('dec_data')
dec
# Out:
#        Order_ID                     Product  Quantity_Ordered   Price_Each  \
# 0      295665.0          Macbook Pro Laptop               1.0  1700.000000
# 1      295666.0          LG Washing Machine               1.0   600.000000
# 2      295667.0        USB-C Charging Cable               1.0    11.950000
# 3      295668.0            27in FHD Monitor               1.0   149.990005
# 4      295669.0        USB-C Charging Cable               1.0    11.950000
# ...         ...                         ...               ...          ...
# 25112  319666.0    Lightning Charging Cable               1.0    14.950000
# 25113  319667.0       AA Batteries (4-pack)               2.0     3.840000
# 25114  319668.0             Vareebadd Phone               1.0   400.000000
# 25115  319669.0            Wired Headphones               1.0    11.990000
# 25116  319670.0  Bose SoundSport Headphones               1.0    99.989998
#
# ...
